# %%
import pickle
import pandas as pd
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import accuracy_score
import joblib

# %%
comment_df = pd.read_csv('comments.csv',index_col='Author')
comment_df
# Out:
#                                                             Comments  Rating
# Author
# Bully Maguire                         like dislike ratio makes proud       4
# Mr. Robloxer                like search disliked netflix trailer get       2
# Pendekar Bayangan  men … trevor noah true bro stop laughing even ...       5
# Fbn 47             feedback essential help us make game great wou...       1
# Amanda Hugankiz               fact k people liked trailer disturbing       2
# ...                                                              ...     ...
# NandoPro007        guy cod ghosts bragging whole fish case defini...       3
# Suad Sadik                  remember every dream requires discipline       3
# Jerrbxb            damn kisaki made way valorant takemichi needs ...       3
# Abhishek Rajput    britishers looted trillion dollars living tree...       2
# Nhilist                              ceo bang energy made game would       2
#
# [958 rows x 2 columns]

# %%
from sklearn.pipeline import make_pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC

clf = make_pipeline(
    TfidfVectorizer(),
    OneVsRestClassifier(SVC(kernel='linear', probability=True))
)

clf = clf.fit(X=comment_df['Comments'], y=comment_df['Rating'])

# %%
text = "worst video ever dont watch this"
clf.predict_proba([text.lower()])
# Out:
# array([[0.43093558, 0.07457753, 0.04056708, 0.12287067, 0.33104914]])

# %%
model_filename = 'model.joblib.z'
joblib.dump(clf, model_filename)
# Out:
# ['model.joblib.z']
